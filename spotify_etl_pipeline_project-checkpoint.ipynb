# %%
# !pip install spotipy
# Out:
# ...
#
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    -------------------- ------------------- 1/2 [spotipy]
#    ---------------------------------------- 2/2 [spotipy]
#
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="2af9b2e7ead04e15b877ef82a4d53437", client_secret="15cbd5300aed45fea1563bf2847968d7")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/6UeSakyzhiEt4NB3UAd6NQ"

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
playlist_URI
# Out:
# '6UeSakyzhiEt4NB3UAd6NQ'

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/6UeSakyzhiEt4NB3UAd6NQ/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2025-11-03T03:24:28Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/billboard.com'},
#     'href': 'https://api.spotify.com/v1/users/billboard.com',
#     'id': 'billboard.com',
#     'type': 'user',
#     'uri': 'spotify:user:billboard.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '4a6NzYL1YHRUgx9e3YZI6I'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'The Life of a Showgirl'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2025-10-03'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 12

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/4a6NzYL1YHRUgx9e3YZI6I'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name, 'release_date':album_release_date,'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '4a6NzYL1YHRUgx9e3YZI6I',
#   'name': 'The Life of a Showgirl',
#   'release_date': '2025-10-03',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/4a6NzYL1YHRUgx9e3YZI6I'},
#  {'album_id': '14JkAa6IiFaOh5s0nMyMU9',
#   'name': 'KPop Demon Hunters (Soundtrack from the Netflix Film)',
#   'release_date': '2025-06-20',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/14JkAa6IiFaOh5s0nMyMU9'},
#  {'album_id': '6xomx5ekO7qHDvDh57rZ5S',
#   'name': 'Ordinary',
#   'release_date': '2025-02-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6xomx5ekO7qHDvDh57rZ5S'},
#  {'album_id': '4a6NzYL1YHRUgx9e3YZI6I',
#   'name': 'The Life of a Showgirl',
#   'release_date': '2025-10-03',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/4a6NzYL1YHRUgx9e3YZI6I'},
#  {'album_id': '4a6NzYL1YHRUgx9e3YZI6I',
#   'name': 'The Life of a Showgirl',
#   'release_date': '2025-10-03',
#   'total_tracks': 12,
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '2yNNYQBChuox9A5Ka93BIn',
#   'artist_name': 'HUNTR/X',
#   'external_url': 'https://api.spotify.com/v1/artists/2yNNYQBChuox9A5Ka93BIn'},
#  {'artist_id': '0RMJOzHDhAKY1o2j0W0vxY',
#   'artist_name': 'EJAE',
#   'external_url': 'https://api.spotify.com/v1/artists/0RMJOzHDhAKY1o2j0W0vxY'},
#  {'artist_id': '0Wwji82sLA0Hcvtuak3omb',
#   'artist_name': 'AUDREY NUNA',
#   'external_url': 'https://api.spotify.com/v1/artists/0Wwji82sLA0Hcvtuak3omb'},
#  {'artist_id': '6U1dV7aL68N7Gb0Naq34V5',
#   'artist_name': 'REI AMI',
#   'external_url': 'https://api.spotify.com/v1/artists/6U1dV7aL68N7Gb0Naq34V5'},
#  {'artist_id': '7mW7Tv7NvywKKXqafZo0Lc',
#   'artist_name': 'KPop Demon Hunters Cast',
#   'external_url': 'https://api.spotify.com/v1/artists/7mW7Tv7NvywKKXqafZo0Lc'},
#  {'artist_id': '0fTSzq9jAh4c36UVb4V7CB',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
